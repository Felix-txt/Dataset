# %%
import pandas as pd

df = pd.read_csv('Google_Stock_Price.csv')

df
# Out:
#      symbol        date        open        high         low       close  \
# 0      GOOG  2018-01-02   52.417000   53.347000   52.261501   53.250000
# 1      GOOG  2018-01-03   53.215500   54.314499   53.160500   54.124001
# 2      GOOG  2018-01-04   54.400002   54.678501   54.200100   54.320000
# 3      GOOG  2018-01-05   54.700001   55.212502   54.599998   55.111500
# 4      GOOG  2018-01-08   55.111500   55.563499   55.081001   55.347000
# ...     ...         ...         ...         ...         ...         ...
# 1756   GOOG  2024-12-24  196.169998  197.669998  195.197998  197.570007
# 1757   GOOG  2024-12-26  196.740005  198.160004  195.869995  197.100006
# 1758   GOOG  2024-12-27  196.470001  196.800003  191.972000  194.039993
# 1759   GOOG  2024-12-30  190.865005  193.779999  190.360001  192.690002
# 1760   GOOG  2024-12-31  192.445007  193.250000  189.580002  190.440002
#
#         volume    adjclose  dividends  splits
# 0     24752000   53.059353        0.0     0.0
# ...

# %%
import matplotlib.pyplot as plt

df['date'] = pd.to_datetime(df['date'])

df.set_index('date', inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(df['close'], label='Google Stock Price (Close)', color='blue')
plt.title('Google Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Stock Price (USD)')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['open'], label='Google Stock Price (Open)', color='red')
plt.title('Google Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Stock Price (USD)')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['high'], label='Google Stock Price (High)', color='red')
plt.plot(df['low'], label='Google Stock Price (Low)', color='blue')
plt.title('Google Stock Price High and Low')
plt.xlabel('date')
plt.ylabel('Stock Price (USD)')
plt.grid()
plt.show()

# %%
ds = df.drop(['dividends', 'splits', 'symbol'], axis=1)
ds
# Out:
#                   open        high         low       close    volume  \
# date
# 2018-01-02   52.417000   53.347000   52.261501   53.250000  24752000
# 2018-01-03   53.215500   54.314499   53.160500   54.124001  28604000
# 2018-01-04   54.400002   54.678501   54.200100   54.320000  20092000
# 2018-01-05   54.700001   55.212502   54.599998   55.111500  25582000
# 2018-01-08   55.111500   55.563499   55.081001   55.347000  20952000
# ...                ...         ...         ...         ...       ...
# 2024-12-24  196.169998  197.669998  195.197998  197.570007   6809800
# 2024-12-26  196.740005  198.160004  195.869995  197.100006   7907900
# 2024-12-27  196.470001  196.800003  191.972000  194.039993  14693000
# 2024-12-30  190.865005  193.779999  190.360001  192.690002  12209500
# 2024-12-31  192.445007  193.250000  189.580002  190.440002  14355200
#
#               adjclose
# date
# 2018-01-02   53.059353
# 2018-01-03   53.930225
# 2018-01-04   54.125519
# 2018-01-05   54.914188
# ...

# %%
import plotly.graph_objs as go

ds.columns = ds.columns.str.strip()

ds['date'] = pd.to_datetime(ds['date'])

ds = ds[(ds['date'] >= '2018-01-01') & (ds['date'] <= '2025-12-31')]

# Skapa grafen
fig = go.Figure()

# Lägg till linje för justerade stängningspriser
fig.add_trace(go.Scatter(x=ds['date'], y=ds['adjclose'], mode='lines', name='Adj Close'))

# Anpassa layout
fig.update_layout(title='Google Stock Price (2018-2025)',
                  xaxis_title='Datum',
                  yaxis_title='Price (USD)',
                  hovermode='closest')

# Visa grafen
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 5
#       1 import plotly.graph_objs as go
# ...
